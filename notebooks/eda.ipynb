# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/LENOVO/OneDrive/Desktop/DMW project/data/processed/ingested.csv")
print(df.head())
# Out:
#         user_id        date   amount        category    payment_type  \
# 0  STU_2024_001  2024-01-01  1200.00            Rent     Credit Card
# 1  STU_2024_001  2024-01-02    45.50   Food & Dining      Debit Card
# 2  STU_2024_001  2024-01-03    12.99   Entertainment  Digital Wallet
# 3  STU_2024_001  2024-01-04    25.00  Transportation            Cash
# 4  STU_2024_001  2024-01-05    85.30       Utilities            Cash
#
#                merchant
# 0  Apartment Management
# 1               Walmart
# 2               Netflix
# 3                  Uber
# 4      Electric Company

# %%
df.shape
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       100 non-null    object
#  1   date          100 non-null    object
#  2   amount        100 non-null    float64
#  3   category      100 non-null    object
#  4   payment_type  100 non-null    object
#  5   merchant      100 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %%
# spedning distribution

import matplotlib.pyplot as plt

df['amount'].hist(bins=30)
plt.title("spending distribution")
plt.show()

# %%
# Category wise spending

df.groupby("category")['amount'].sum().sort_values().plot(kind='barh')
plt.title("spending by category")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure columns exist
df['month'] = pd.to_datetime(df['date']).dt.strftime('%b')  # e.g., Jan, Feb...

df.groupby('month')['amount'].sum().plot(kind='bar')
plt.title("Monthly Spending Trend")
plt.tight_layout()
plt.show()

# %%
# user wise behaviour 

df.groupby('user_id')['amount'].sum().sort_values(ascending=False).head(10)
# Out:
# user_id
# STU_2024_003    5453.18
# STU_2024_001    3521.95
# STU_2024_005    3131.37
# STU_2024_002    2231.92
# STU_2024_004    1541.92
# Name: amount, dtype: float64

# %%
# payment type analysis 

df.groupby('payment_type')['amount'].sum().plot(kind='bar')
plt.title("Payment Type Usage")
plt.show()

# %%
# outlier boxplot 

sns.boxplot(x=df['amount'])
plt.title("Outlier Detection - Amount")
plt.show()

# %%
user_spend = df.groupby('user_id')['amount'].sum()

sns.histplot(user_spend, bins=20)
plt.title("User Total Spending Distribution")
plt.show()

# %%
import seaborn as sns

sns.scatterplot(
    x=df['total_spend'],
    y=df['avg_spend'],
    hue=df['cluster']
)
plt.title("User Segmentation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_spend'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 import seaborn as sns
# ...
